# %% [markdown]
# # Explore here

# %%
import pandas as pd
import requests

# %%
url = "https://data.lacity.org/resource/2nrs-mtv8.json?$select=*&$limit=650684&$offset=0"
response = requests.get(url).json()

# %%
total_data=pd.DataFrame(response)
total_data
# Out:
#             dr_no                date_rptd                 date_occ time_occ  \
# 0       010304468  2020-01-08T00:00:00.000  2020-01-08T00:00:00.000     2230
# 1       190101086  2020-01-02T00:00:00.000  2020-01-01T00:00:00.000     0330
# 2       200110444  2020-04-14T00:00:00.000  2020-02-13T00:00:00.000     1200
# 3       191501505  2020-01-01T00:00:00.000  2020-01-01T00:00:00.000     1730
# 4       191921269  2020-01-01T00:00:00.000  2020-01-01T00:00:00.000     0415
# ...           ...                      ...                      ...      ...
# 650679  230507351  2023-04-02T00:00:00.000  2023-04-02T00:00:00.000     2230
# 650680  230311115  2023-05-19T00:00:00.000  2023-05-14T00:00:00.000     1600
# 650681  231111474  2023-07-24T00:00:00.000  2023-07-22T00:00:00.000     2130
# 650682  231517676  2023-11-15T00:00:00.000  2023-11-15T00:00:00.000     1150
# 650683  231210774  2023-04-21T00:00:00.000  2023-02-23T00:00:00.000     1200
#
# ...

# %%
total_data.to_csv("../data/raw/total_data.csv")
